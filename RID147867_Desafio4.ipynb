# %% [markdown]
# <a href="https://colab.research.google.com/github/FelipeNunesReis/Projetos.Aulas-DNC/blob/main/RID147867_Desafio4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Análise Descritiva**

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-4e0ef284-d390-4438-be44-c9ac5f30cc54" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4e0ef284-d390-4438-be44-c9ac5f30cc54">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('MKT.csv')

# %%
df.head()
# Out:
#    youtube  facebook  newspaper  sales
# 0    84.72     19.20      48.96  12.60
# 1   351.48     33.96      51.84  25.68
# 2   135.48     20.88      46.32  14.28
# 3   116.64      1.80      36.00  11.52
# 4   318.72     24.00       0.36  20.88

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   youtube    171 non-null    float64
#  1   facebook   171 non-null    float64
#  2   newspaper  171 non-null    float64
#  3   sales      171 non-null    float64
# dtypes: float64(4)
# memory usage: 5.5 KB

# %%
df.dtypes
# Out:
# youtube      float64
# facebook     float64
# newspaper    float64
# sales        float64
# dtype: object

# %%
df.describe()
# Out:
#           youtube    facebook   newspaper       sales
# count  171.000000  171.000000  171.000000  171.000000
# mean   178.021053   27.671579   35.240000   16.922807
# std    102.449597   17.913532   24.902918    6.314608
# min      0.840000    0.000000    0.360000    1.920000
# 25%     91.080000   11.700000   13.740000   12.540000
# 50%    179.760000   26.760000   31.080000   15.480000
# 75%    262.980000   43.680000   50.880000   20.820000
# max    355.680000   59.520000  121.080000   32.400000

# %% [markdown]
# # **Análise Explorátoria**
#
#
#
#
#
# Baseado nos dados, é possivel identificar que é dados de tráfego pago.
#
# E através de algumas analises exploratórias, foi possível identificar que o número de venda não está ligada a quantidade do valor investido em um única rede de tráfego, mas no conjunto.
#
# Após a verificação de dessas analises o máximo valor de sales não esta ligado a nenhum valor máximo investido nas plataformas de tráfego.

# %%
sales_max_index = df['sales'].idxmax()
facebook_max_index = df['facebook'].idxmax()
youtube_max_index = df['youtube'].idxmax()
newspaper_max_index = df['newspaper'].idxmax()

# %%
df.loc[sales_max_index,['youtube','facebook','newspaper']]
# Out:
# youtube      332.28
# facebook      58.68
# newspaper     50.16
# Name: 146, dtype: float64

# %%
df.loc[facebook_max_index,['youtube','newspaper','sales']]
# Out:
# youtube      252.96
# newspaper     45.24
# sales         28.56
# Name: 29, dtype: float64

# %%
df.loc[youtube_max_index,['facebook','newspaper','sales']]
# Out:
# facebook      43.56
# newspaper    121.08
# sales         28.56
# Name: 72, dtype: float64

# %%
df.loc[newspaper_max_index,['facebook','youtube','sales']]
# Out:
# facebook     43.56
# youtube     355.68
# sales        28.56
# Name: 72, dtype: float64

# %%
df[(df['facebook']>43.56)&(df['youtube']<355.68)]
# Out:
#      youtube  facebook  newspaper  sales
# 7     320.28     52.56       6.00  30.48
# 8      89.64     59.28      54.84  17.64
# 10    273.60     45.24      38.40  25.80
# 18    287.88     49.80      22.20  27.84
# 23    259.68     50.04      47.52  27.12
# 24    219.12     55.44      70.44  25.44
# 26    238.68     59.28      72.00  28.44
# 29    252.96     59.52      45.24  28.56
# 32    313.56     51.24      65.64  29.04
# 35    157.32     51.36      34.68  21.60
# 40    260.16     52.68      32.64  26.76
# 46     20.28     52.44     107.28  10.44
# 54     82.08     53.40      42.72  16.32
# 55    256.20     51.60      40.56  26.04
# 58    132.84     48.72      75.84  19.20
# 60    131.76     57.36      61.68  20.04
# 64    301.08     43.80      86.76  26.64
# 69    347.64     50.76      61.44  30.48
# 70    162.24     50.04      55.08  20.64
# 76    165.48     55.68      70.80  23.04
# 82    290.04     45.60      27.84  26.16
# 85     93.84     56.16      41.40  17.52
# ...

# %%
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# %%
px.box(df, x = 'sales')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.histplot(df['sales'])
# Out:
# <Axes: xlabel='sales', ylabel='Count'>

# %%
ax = px.bar(df[(df['facebook']>43.56)&(df['youtube']<355.68)], x ='facebook',y='sales')
ax
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ax = px.bar(df[(df['newspaper']>50.16)&(df['youtube']<355.68)], x ='newspaper',y='sales')
ax
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ax = px.bar(df[(df['youtube']>=250)&(df['youtube']<355.68)], x ='youtube',y='sales')
ax
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Modelagem**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X= df[['youtube','facebook','newspaper']]
Y= df[['sales']]

# %%
X_train, X_teste, Y_train, Y_teste = train_test_split(X, Y, train_size = 0.7, random_state = 15 )

# %%
lm= LinearRegression()

# %%
lm.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # **Calculando predição**

# %%
y_pred = lm.predict(X_teste)

# %%
from sklearn.metrics import r2_score
r= r2_score(Y_teste, y_pred)

# %%
print('r_quadrado', r)
# Out:
# r_quadrado 0.8849798897507577

# %%
youtube = 0
facebook = 200
newspaper =0
entrada= [[youtube,facebook,newspaper]]
lm.predict(entrada)[0]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning:
#
# X does not have valid feature names, but LinearRegression was fitted with feature names
# array([41.78538848])

# %% [markdown]
# # **Conclusão do desafio**
# Após a realização das modelagem, meu objetivo foi verificar qual dos meios de publicidades que mais afetavam o **SALES**, analisando os gráficos verifiquei que o meio de publicidade **newspaper** não interfere no aumento de vendas (SALES), os meios que mais afetam é o Youtube e Facebook, a minha conclusão é que a empresa pode deixar de investir em newspaper como meio de publicidade, aumentar o investimento em publicidade priorizando o Facebook e diminuindo o investimento no youtube para aplicação desse para investir no Facebook.
